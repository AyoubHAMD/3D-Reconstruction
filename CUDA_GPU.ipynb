# %% [markdown]
# <a href="https://colab.research.google.com/github/AyoubHAMD/3D-Reconstruction/blob/master/CUDA_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Nvidia & other dependencies

# %%
! add-apt-repository ppa:graphics-drivers/ppa
! apt update
! apt install nvidia-384 nvidia-384-dev
! apt-get install g++ freeglut3-dev build-essential libx11-dev libxmu-dev libxi-dev libglu1-mesa libglu1-mesa-dev
# Out:
# /bin/sh: 1: add-apt-repository: not found
# Get:1 file:/var/cuda-repo-9-2-local-cublas-update-1  InRelease
# Ign:1 file:/var/cuda-repo-9-2-local-cublas-update-1  InRelease
# Get:2 file:/var/cuda-repo-9-2-local  InRelease
# Ign:2 file:/var/cuda-repo-9-2-local  InRelease
# Get:3 file:/var/cuda-repo-9-2-local-cublas-update-1  Release [574 B]
# Get:4 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:3 file:/var/cuda-repo-9-2-local-cublas-update-1  Release [574 B]
# Get:5 file:/var/cuda-repo-9-2-local-cublas-update-1  Release.gpg [801 B]
# Get:4 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:5 file:/var/cuda-repo-9-2-local-cublas-update-1  Release.gpg [801 B]
# Hit:6 http://archive.ubuntu.com/ubuntu artful InRelease
# Get:8 http://archive.ubuntu.com/ubuntu artful-updates InRelease [88.7 kB]
# Get:9 file:/var/cuda-repo-9-2-local-cublas-update-1  Packages [690 B]
# Get:10 http://archive.ubuntu.com/ubuntu artful-backports InRelease [74.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful-updates/universe Sources [42.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu artful-updates/universe amd64 Packages [139 kB]
# Get:13 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 Packages [345 kB]
# Get:14 http://security.ubuntu.com/ubuntu artful-security InRelease [83.2 kB]
# Get:15 http://security.ubuntu.com/ubuntu artful-security/universe Sources [20.5 kB]
# Fetched 793 kB in 1s (448 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 4 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   ca-certificates-java cuda-command-line-tools-9-2 cuda-compiler-9-2
#   cuda-cublas-9-2 cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2
#   cuda-cufft-9-2 cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2
#   cuda-curand-9-2 cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-documentation-9-2
#   cuda-driver-dev-9-2 cuda-gdb-9-2 cuda-gpu-library-advisor-9-2
#   cuda-libraries-9-2 cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-samples-9-2
#   cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2 default-jre
#   default-jre-headless fonts-dejavu-extra java-common libatk-wrapper-java
#   libatk-wrapper-java-jni libcusparse8.0 libgif7 libnppc8.0 libnppi8.0
#   libnppial8.0 libnppicc8.0 libnppicom8.0 libnppidei8.0 libnppif8.0
#   libnppig8.0 libnppim8.0 libnppist8.0 libnppisu8.0 libnppitc8.0 libnpps8.0
#   libnvblas8.0 libnvgraph8.0 libnvrtc8.0 libnvtoolsext1 libnvvm3 libthrust-dev
#   libvdpau-dev nvidia-cuda-doc nvidia-cuda-gdb nvidia-modprobe
#   nvidia-opencl-dev ocl-icd-libopencl1 opencl-c-headers opencl-clhpp-headers
#   opencl-headers openjdk-8-jre openjdk-8-jre-headless
# Use 'apt autoremove' to remove them.
# Recommended packages:
#   libcuda1-384 nvidia-opencl-icd-384
# The following packages will be REMOVED:
#   cuda cuda-9-2 cuda-demo-suite-9-2 cuda-drivers cuda-runtime-9-2 libcuda1-396
#   libcuinj64-8.0 nvidia-396 nvidia-396-dev nvidia-cuda-dev nvidia-cuda-toolkit
#   nvidia-opencl-icd-396 nvidia-profiler nvidia-visual-profiler
# The following NEW packages will be installed:
#   nvidia-384 nvidia-384-dev
# 0 upgraded, 2 newly installed, 14 to remove and 4 not upgraded.
# Need to get 76.7 MB of archives.
# After this operation, 908 MB disk space will be freed.
# Get:1 http://archive.ubuntu.com/ubuntu artful-updates/restricted amd64 nvidia-384 amd64 384.111-0ubuntu0.17.10.1 [76.6 MB]
# Get:2 http://archive.ubuntu.com/ubuntu artful-updates/restricted amd64 nvidia-384-dev amd64 384.111-0ubuntu0.17.10.1 [82.1 kB]
# Fetched 76.7 MB in 3s (23.7 MB/s)
#
# (Reading database ... 97432 files and directories currently installed.)
# Removing cuda (9.2.88-1) ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  1%] [#.........................................................] 87Progress: [  3%] [##........................................................] 8
# 7Progress: [  5%] [###.......................................................] 8Removing cuda-9-2 (9.2.88-1) ...
# 7Progress: [  7%] [####......................................................] 87Progress: [  9%] [#####.....................................................] 87Progress: [ 11%] [######....................................................] 8Removing cuda-demo-suite-9-2 (9.2.88-1) ...
# 7Progress: [ 13%] [#######...................................................] 87Progress: [ 15%] [########..................................................] 87Progress: [ 16%] [#########.................................................] 8Removing cuda-runtime-9-2 (9.2.88-1) ...
# 7Progress: [ 18%] [##########................................................] 87Progress: [ 20%] [############..............................................] 87Progress: [ 22%] [#############.............................................] 8Removing cuda-drivers (396.26-1) ...
# 7Progress: [ 24%] [##############............................................] 87Progress: [ 26%] [###############...........................................] 87Progress: [ 28%] [################..........................................] 8Removing nvidia-cuda-toolkit (8.0.61-1) ...
# 7Progress: [ 30%] [#################.........................................] 87Progress: [ 32%] [##################........................................] 87Progress: [ 33%] [###################.......................................] 8Removing nvidia-cuda-dev (8.0.61-1) ...
# 7Progress: [ 35%] [####################......................................] 87Progress: [ 37%] [#####################.....................................] 87Progress: [ 39%] [######################....................................] 8Removing nvidia-visual-profiler (8.0.61-1) ...
# 7Progress: [ 41%] [########################..................................] 87Progress: [ 43%] [#########################.................................] 87Progress: [ 45%] [##########################................................] 8Removing nvidia-profiler (8.0.61-1) ...
# 7Progress: [ 47%] [###########################...............................] 87Progress: [ 49%] [############################..............................] 87Progress: [ 50%] [#############################.............................] 8Removing libcuinj64-8.0:amd64 (8.0.61-1) ...
# 7Progress: [ 52%] [##############################............................] 87Progress: [ 54%] [###############################...........................] 87Progress: [ 56%] [################################..........................] 8Removing libcuda1-396 (396.26-0ubuntu1) ...
# 7Progress: [ 58%] [#################################.........................] 87Progress: [ 60%] [###################################.......................] 87Progress: [ 62%] [####################################......................] 8Removing nvidia-opencl-icd-396 (396.26-0ubuntu1) ...
# 7Progress: [ 64%] [#####################################.....................] 87Progress: [ 66%] [######################################....................] 87Progress: [ 67%] [#######################################...................] 8Removing nvidia-396-dev (396.26-0ubuntu1) ...
# 7Progress: [ 69%] [########################################..................] 87Progress: [ 71%] [#########################################.................] 87Progress: [ 73%] [##########################################................] 8Removing nvidia-396 (396.26-0ubuntu1) ...
# 7Progress: [ 75%] [###########################################...............] 8Failed to connect to bus: No such file or directory
# Removing all DKMS Modules
# Done.
# update-alternatives: using /usr/lib/nvidia-396-prime/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-396-prime/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-396-prime/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_GL.conf (i386-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-396-prime/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_EGL.conf (i386-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa-egl/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# 7Progress: [ 77%] [############################################..............] 87Progress: [ 79%] [#############################################.............] 8Selecting previously unselected package nvidia-384.
# (Reading database ... 93059 files and directories currently installed.)
# Preparing to unpack .../nvidia-384_384.111-0ubuntu0.17.10.1_amd64.deb ...
# 7Progress: [ 81%] [###############################################...........] 8Unpacking nvidia-384 (384.111-0ubuntu0.17.10.1) ...
# 7Progress: [ 83%] [################################################..........] 87Progress: [ 84%] [#################################################.........] 8Selecting previously unselected package nvidia-384-dev.
# Preparing to unpack .../nvidia-384-dev_384.111-0ubuntu0.17.10.1_amd64.deb ...
# 7Progress: [ 86%] [##################################################........] 8Unpacking nvidia-384-dev (384.111-0ubuntu0.17.10.1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 90%] [####################################################......] 8Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up nvidia-384 (384.111-0ubuntu0.17.10.1) ...
# 7Progress: [ 92%] [#####################################################.....] 8update-alternatives: using /usr/lib/nvidia-384/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-384/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-384/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_GL.conf (i386-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-384/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_EGL.conf (i386-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/share/nvidia-384/glamor.conf to provide /usr/share/X11/xorg.conf.d/glamoregl.conf (glamor_conf) in auto mode
# Adding system user `nvidia-persistenced' (UID 111) ...
# Adding new group `nvidia-persistenced' (GID 115) ...
# Adding new user `nvidia-persistenced' (UID 111) with group `nvidia-persistenced' ...
# Not creating home directory `/'.
# Loading new nvidia-384-384.111 DKMS files...
# It is likely that 4.4.111+ belongs to a chroot's host
# Building for 4.13.0-43-generic
# Building for architecture x86_64
# Building initial module for 4.13.0-43-generic
# Done.
#
# nvidia_384:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# nvidia_384_modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# nvidia_384_drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# nvidia_384_uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# 7Progress: [ 94%] [######################################################....] 8Processing triggers for man-db (2.7.6.1-2) ...
# Setting up nvidia-384-dev (384.111-0ubuntu0.17.10.1) ...
# 7Progress: [ 96%] [#######################################################...] 87Progress: [ 98%] [########################################################..] 8Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# g++ is already the newest version (4:7.2.0-1ubuntu1).
# libglu1-mesa is already the newest version (9.0.0-2.1build1).
# libglu1-mesa-dev is already the newest version (9.0.0-2.1build1).
# libx11-dev is already the newest version (2:1.6.4-3).
# libxi-dev is already the newest version (2:1.7.9-1).
# libxmu-dev is already the newest version (2:1.1.2-2).
# freeglut3-dev is already the newest version (2.8.1-3).
# The following packages were automatically installed and are no longer required:
#   ca-certificates-java cuda-command-line-tools-9-2 cuda-compiler-9-2
#   cuda-cublas-9-2 cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2
#   cuda-cufft-9-2 cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2
#   cuda-curand-9-2 cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-documentation-9-2
#   cuda-driver-dev-9-2 cuda-gdb-9-2 cuda-gpu-library-advisor-9-2
#   cuda-libraries-9-2 cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-samples-9-2
#   cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2 default-jre
#   default-jre-headless fonts-dejavu-extra java-common libatk-wrapper-java
#   libatk-wrapper-java-jni libcusparse8.0 libgif7 libnppc8.0 libnppi8.0
#   libnppial8.0 libnppicc8.0 libnppicom8.0 libnppidei8.0 libnppif8.0
#   libnppig8.0 libnppim8.0 libnppist8.0 libnppisu8.0 libnppitc8.0 libnpps8.0
#   libnvblas8.0 libnvgraph8.0 libnvrtc8.0 libnvtoolsext1 libnvvm3 libthrust-dev
#   libvdpau-dev nvidia-cuda-doc nvidia-cuda-gdb nvidia-modprobe
#   nvidia-opencl-dev ocl-icd-libopencl1 opencl-c-headers opencl-clhpp-headers
#   opencl-headers openjdk-8-jre openjdk-8-jre-headless
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %% [markdown]
# # Show our GPU

# %%
! nvidia-smi
# Out:
# Tue May 22 16:19:39 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8    27W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # C Compiler

# %%
# !gcc -v
# Out:
# Using built-in specs.
# COLLECT_GCC=gcc
# COLLECT_LTO_WRAPPER=/usr/lib/gcc/x86_64-linux-gnu/7/lto-wrapper
# OFFLOAD_TARGET_NAMES=nvptx-none
# OFFLOAD_TARGET_DEFAULT=1
# Target: x86_64-linux-gnu
# Configured with: ../src/configure -v --with-pkgversion='Ubuntu 7.2.0-8ubuntu3.2' --with-bugurl=file:///usr/share/doc/gcc-7/README.Bugs --enable-languages=c,ada,c++,go,brig,d,fortran,objc,obj-c++ --prefix=/usr --with-gcc-major-version-only --program-suffix=-7 --program-prefix=x86_64-linux-gnu- --enable-shared --enable-linker-build-id --libexecdir=/usr/lib --without-included-gettext --enable-threads=posix --libdir=/usr/lib --enable-nls --with-sysroot=/ --enable-clocale=gnu --enable-libstdcxx-debug --enable-libstdcxx-time=yes --with-default-libstdcxx-abi=new --enable-gnu-unique-object --disable-vtable-verify --enable-libmpx --enable-plugin --enable-default-pie --with-system-zlib --with-target-system-zlib --enable-objc-gc=auto --enable-multiarch --disable-werror --with-arch-32=i686 --with-abi=m64 --with-multilib-list=m32,m64,mx32 --enable-multilib --with-tune=generic --enable-offload-targets=nvptx-none --without-cuda-driver --enable-checking=release --build=x86_64-linux-gnu --host=x86_64-linux-gnu --target=x86_64-linux-gnu
# Thread model: posix
# gcc version 7.2.0 (Ubuntu 7.2.0-8ubuntu3.2)

# %%
# !apt install gcc-6
# !apt install g++-6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gcc-6 is already the newest version (6.4.0-8ubuntu1).
# The following packages were automatically installed and are no longer required:
#   ca-certificates-java cuda-command-line-tools-9-2 cuda-compiler-9-2
#   cuda-cublas-9-2 cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2
#   cuda-cufft-9-2 cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2
#   cuda-curand-9-2 cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-documentation-9-2
#   cuda-driver-dev-9-2 cuda-gdb-9-2 cuda-gpu-library-advisor-9-2
#   cuda-libraries-9-2 cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-samples-9-2
#   cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2 default-jre
#   default-jre-headless fonts-dejavu-extra java-common libatk-wrapper-java
#   libatk-wrapper-java-jni libcusparse8.0 libgif7 libnppc8.0 libnppi8.0
#   libnppial8.0 libnppicc8.0 libnppicom8.0 libnppidei8.0 libnppif8.0
#   libnppig8.0 libnppim8.0 libnppist8.0 libnppisu8.0 libnppitc8.0 libnpps8.0
#   libnvblas8.0 libnvgraph8.0 libnvrtc8.0 libnvtoolsext1 libnvvm3 libthrust-dev
#   libvdpau-dev nvidia-cuda-doc nvidia-cuda-gdb nvidia-modprobe
#   nvidia-opencl-dev ocl-icd-libopencl1 opencl-c-headers opencl-clhpp-headers
#   opencl-headers openjdk-8-jre openjdk-8-jre-headless
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# g++-6 is already the newest version (6.4.0-8ubuntu1).
# The following packages were automatically installed and are no longer required:
#   ca-certificates-java cuda-command-line-tools-9-2 cuda-compiler-9-2
#   cuda-cublas-9-2 cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2
#   cuda-cufft-9-2 cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2
#   cuda-curand-9-2 cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-documentation-9-2
#   cuda-driver-dev-9-2 cuda-gdb-9-2 cuda-gpu-library-advisor-9-2
#   cuda-libraries-9-2 cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-samples-9-2
#   cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2 default-jre
#   default-jre-headless fonts-dejavu-extra java-common libatk-wrapper-java
#   libatk-wrapper-java-jni libcusparse8.0 libgif7 libnppc8.0 libnppi8.0
#   libnppial8.0 libnppicc8.0 libnppicom8.0 libnppidei8.0 libnppif8.0
#   libnppig8.0 libnppim8.0 libnppist8.0 libnppisu8.0 libnppitc8.0 libnpps8.0
#   libnvblas8.0 libnvgraph8.0 libnvrtc8.0 libnvtoolsext1 libnvvm3 libthrust-dev
#   libvdpau-dev nvidia-cuda-doc nvidia-cuda-gdb nvidia-modprobe
#   nvidia-opencl-dev ocl-icd-libopencl1 opencl-c-headers opencl-clhpp-headers
#   opencl-headers openjdk-8-jre openjdk-8-jre-headless
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %% [markdown]
# # Install CUDA

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64
# Out:
# --2018-05-22 16:19:51--  https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.deb?B7HcsdVEn5AJFVd57BNchXhjRAVuoGtzBgwPHlEjiCEpJIDnGTFrKqMXKvD1xIoemUfUP22vQVXaUxuKQmTxJgqNbBSW34afIUvRfT3RWrJhEkzamjmCSU-TVqNn4dEqQTJpjTSKQwzjwXKMHiLJQaK7zOpcMaVaqZZoVBG2964iilnDa13vt3nkdIW4wCaP-4IwrpxRUySXJs2HvIU [following]
# --2018-05-22 16:19:51--  https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.deb?B7HcsdVEn5AJFVd57BNchXhjRAVuoGtzBgwPHlEjiCEpJIDnGTFrKqMXKvD1xIoemUfUP22vQVXaUxuKQmTxJgqNbBSW34afIUvRfT3RWrJhEkzamjmCSU-TVqNn4dEqQTJpjTSKQwzjwXKMHiLJQaK7zOpcMaVaqZZoVBG2964iilnDa13vt3nkdIW4wCaP-4IwrpxRUySXJs2HvIU
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.211.70, 2606:2800:21f:3aa:dcf:37b:1ed6:1fb
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.211.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1269204396 (1.2G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.1’
#
# cuda-repo-ubuntu171 100%[===================>]   1.18G   153MB/s    in 8.8s
#
# 2018-05-22 16:20:00 (137 MB/s) - ‘cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.1’ saved [1269204396/1269204396]

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/patches/1/cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64
# Out:
# --2018-05-22 16:20:02--  https://developer.nvidia.com/compute/cuda/9.2/Prod/patches/1/cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/patches/1/cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64.deb?cclZuspjs5j_21a38c0V6v9-zmVR1Bzg7vlkN3c6Rtr-OL0iW9HMIZ6Q24wcdBTJcJqmX1u5IPQFixzb83McN7slKmA-XqJpfX67UzlZbbD3zvJ_uKiPw5Fb6VnYV7DneRqPn7oyUc8V8N3WWtlvqrFxGzJh-ghtSiUbq6n_YjPcRnkw5S_TMymK5wsWV9_eof4HdNm1jX_v8ZlSjIQ72TZF4Eg [following]
# --2018-05-22 16:20:03--  https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/patches/1/cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64.deb?cclZuspjs5j_21a38c0V6v9-zmVR1Bzg7vlkN3c6Rtr-OL0iW9HMIZ6Q24wcdBTJcJqmX1u5IPQFixzb83McN7slKmA-XqJpfX67UzlZbbD3zvJ_uKiPw5Fb6VnYV7DneRqPn7oyUc8V8N3WWtlvqrFxGzJh-ghtSiUbq6n_YjPcRnkw5S_TMymK5wsWV9_eof4HdNm1jX_v8ZlSjIQ72TZF4Eg
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.211.70, 2606:2800:21f:3aa:dcf:37b:1ed6:1fb
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.211.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98576578 (94M) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64.1’
#
# cuda-repo-ubuntu171 100%[===================>]  94.01M   142MB/s    in 0.7s
#
# 2018-05-22 16:20:03 (142 MB/s) - ‘cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64.1’ saved [98576578/98576578]

# %%
# !dpkg -i cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64
# Out:
# (Reading database ... 93630 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64 ...
# Unpacking cuda-repo-ubuntu1710-9-2-local (9.2.88-1) over (9.2.88-1) ...
# Setting up cuda-repo-ubuntu1710-9-2-local (9.2.88-1) ...

# %%
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# Out:
# OK

# %%
# !apt-get update
# Out:
# Get:1 file:/var/cuda-repo-9-2-local-cublas-update-1  InRelease
# Ign:1 file:/var/cuda-repo-9-2-local-cublas-update-1  InRelease
# Get:2 file:/var/cuda-repo-9-2-local  InRelease
# Ign:2 file:/var/cuda-repo-9-2-local  InRelease
# Get:3 file:/var/cuda-repo-9-2-local-cublas-update-1  Release [574 B]
# Get:4 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:3 file:/var/cuda-repo-9-2-local-cublas-update-1  Release [574 B]
# Get:4 file:/var/cuda-repo-9-2-local  Release [574 B]
# Hit:5 http://archive.ubuntu.com/ubuntu artful InRelease
# Hit:6 http://security.ubuntu.com/ubuntu artful-security InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu artful-updates InRelease
# Get:9 http://archive.ubuntu.com/ubuntu artful-backports InRelease [74.6 kB]
# Fetched 74.6 kB in 1s (66.0 kB/s)
# Reading package lists... Done

# %%
# !apt-get install cuda
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libcusparse8.0 libnppc8.0 libnppi8.0 libnppial8.0 libnppicc8.0 libnppicom8.0
#   libnppidei8.0 libnppif8.0 libnppig8.0 libnppim8.0 libnppist8.0 libnppisu8.0
#   libnppitc8.0 libnpps8.0 libnvblas8.0 libnvgraph8.0 libnvrtc8.0
#   libnvtoolsext1 libnvvm3 libthrust-dev libvdpau-dev nvidia-cuda-doc
#   nvidia-cuda-gdb nvidia-opencl-dev opencl-c-headers opencl-clhpp-headers
#   opencl-headers
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   cuda-9-2 cuda-demo-suite-9-2 cuda-drivers cuda-runtime-9-2 libcuda1-396
#   nvidia-396 nvidia-396-dev nvidia-opencl-icd-396
# The following packages will be REMOVED:
#   nvidia-384 nvidia-384-dev
# The following NEW packages will be installed:
#   cuda cuda-9-2 cuda-demo-suite-9-2 cuda-drivers cuda-runtime-9-2 libcuda1-396
#   nvidia-396 nvidia-396-dev nvidia-opencl-icd-396
# 0 upgraded, 9 newly installed, 2 to remove and 4 not upgraded.
# Need to get 0 B/91.0 MB of archives.
# After this operation, 101 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-9-2-local  nvidia-396 396.26-0ubuntu1 [80.0 MB]
# Get:2 file:/var/cuda-repo-9-2-local  nvidia-396-dev 396.26-0ubuntu1 [81.7 kB]
# Get:3 file:/var/cuda-repo-9-2-local  libcuda1-396 396.26-0ubuntu1 [3,467 kB]
# Get:4 file:/var/cuda-repo-9-2-local  nvidia-opencl-icd-396 396.26-0ubuntu1 [3,590 kB]
# Get:5 file:/var/cuda-repo-9-2-local  cuda-drivers 396.26-1 [2,386 B]
# Get:6 file:/var/cuda-repo-9-2-local  cuda-runtime-9-2 9.2.88-1 [2,530 B]
# Get:7 file:/var/cuda-repo-9-2-local  cuda-demo-suite-9-2 9.2.88-1 [3,889 kB]
# Get:8 file:/var/cuda-repo-9-2-local  cuda-9-2 9.2.88-1 [2,560 B]
# Get:9 file:/var/cuda-repo-9-2-local  cuda 9.2.88-1 [2,508 B]
# (Reading database ... 93630 files and directories currently installed.)
# Removing nvidia-384-dev (384.111-0ubuntu0.17.10.1) ...
# Removing nvidia-384 (384.111-0ubuntu0.17.10.1) ...
# Failed to connect to bus: No such file or directory
# Removing all DKMS Modules
# Done.
# update-alternatives: using /usr/lib/nvidia-384-prime/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-384-prime/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-384-prime/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_GL.conf (i386-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-384-prime/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_EGL.conf (i386-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa-egl/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# Selecting previously unselected package nvidia-396.
# (Reading database ... 93059 files and directories currently installed.)
# Preparing to unpack .../0-nvidia-396_396.26-0ubuntu1_amd64.deb ...
# Unpacking nvidia-396 (396.26-0ubuntu1) ...
# Selecting previously unselected package nvidia-396-dev.
# Preparing to unpack .../1-nvidia-396-dev_396.26-0ubuntu1_amd64.deb ...
# Unpacking nvidia-396-dev (396.26-0ubuntu1) ...
# Selecting previously unselected package libcuda1-396.
# Preparing to unpack .../2-libcuda1-396_396.26-0ubuntu1_amd64.deb ...
# Unpacking libcuda1-396 (396.26-0ubuntu1) ...
# Selecting previously unselected package nvidia-opencl-icd-396.
# Preparing to unpack .../3-nvidia-opencl-icd-396_396.26-0ubuntu1_amd64.deb ...
# Unpacking nvidia-opencl-icd-396 (396.26-0ubuntu1) ...
# Selecting previously unselected package cuda-drivers.
# Preparing to unpack .../4-cuda-drivers_396.26-1_amd64.deb ...
# Unpacking cuda-drivers (396.26-1) ...
# Selecting previously unselected package cuda-runtime-9-2.
# Preparing to unpack .../5-cuda-runtime-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-runtime-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-demo-suite-9-2.
# Preparing to unpack .../6-cuda-demo-suite-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-demo-suite-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda-9-2.
# Preparing to unpack .../7-cuda-9-2_9.2.88-1_amd64.deb ...
# Unpacking cuda-9-2 (9.2.88-1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../8-cuda_9.2.88-1_amd64.deb ...
# Unpacking cuda (9.2.88-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up nvidia-396 (396.26-0ubuntu1) ...
# update-alternatives: using /usr/lib/nvidia-396/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# update-alternatives: warning: skip creation of /usr/share/grub-gfxpayload-lists/blacklist/10_proprietary-graphics-drivers because associated file /usr/share/nvidia-396/nvidia-396.grub-gfxpayload (of link group x86_64-linux-gnu_gl_conf) doesn't exist
# update-alternatives: using /usr/lib/nvidia-396/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-396/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_GL.conf (i386-linux-gnu_gl_conf) in auto mode
# update-alternatives: using /usr/lib/nvidia-396/alt_ld.so.conf to provide /etc/ld.so.conf.d/i386-linux-gnu_EGL.conf (i386-linux-gnu_egl_conf) in auto mode
# update-alternatives: using /usr/share/nvidia-396/glamor.conf to provide /usr/share/X11/xorg.conf.d/glamoregl.conf (glamor_conf) in auto mode
#
# A modprobe blacklist file has been created at /etc/modprobe.d to prevent Nouveau from loading. This can be reverted by deleting /etc/modprobe.d/nvidia-graphics-drivers.conf.
# A new initrd image has also been created. To revert, please replace /boot/initrd-4.4.111+ with /boot/initrd-$(uname -r)-backup.
#
# *****************************************************************************
# *** Reboot your computer and verify that the NVIDIA graphics driver can   ***
# *** be loaded.                                                            ***
# *****************************************************************************
#
# Adding system user `nvidia-persistenced' (UID 111) ...
# Adding new group `nvidia-persistenced' (GID 115) ...
# Adding new user `nvidia-persistenced' (UID 111) with group `nvidia-persistenced' ...
# Not creating home directory `/'.
# Loading new nvidia-396-396.26 DKMS files...
# It is likely that 4.4.111+ belongs to a chroot's host
# Building for 4.13.0-43-generic
# Building for architecture x86_64
# Building initial module for 4.13.0-43-generic
# Done.
#
# nvidia_396:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# nvidia_396_modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# nvidia_396_drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# nvidia_396_uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-43-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Processing triggers for man-db (2.7.6.1-2) ...
# Setting up libcuda1-396 (396.26-0ubuntu1) ...
# Setting up nvidia-396-dev (396.26-0ubuntu1) ...
# Setting up nvidia-opencl-icd-396 (396.26-0ubuntu1) ...
# Setting up cuda-drivers (396.26-1) ...
# Setting up cuda-runtime-9-2 (9.2.88-1) ...
# Setting up cuda-demo-suite-9-2 (9.2.88-1) ...
# Setting up cuda-9-2 (9.2.88-1) ...
# Setting up cuda (9.2.88-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...

# %%
# !dpkg -i cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64
# Out:
# (Reading database ... 93714 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64 ...
# Unpacking cuda-repo-ubuntu1710-9-2-local-cublas-update-1 (1.0-1) over (1.0-1) ...
# Setting up cuda-repo-ubuntu1710-9-2-local-cublas-update-1 (1.0-1) ...

# %%
# !ls
# Out:
# CUDA-GPU-Contrast-Enhancement
# cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64
# cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.1
# cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64
# cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64.1
# datalab

# %% [markdown]
# # Install CUDA Toolkit

# %%
# !apt-get install nvidia-cuda-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libcuinj64-8.0 nvidia-cuda-dev nvidia-profiler nvidia-visual-profiler
# Suggested packages:
#   libcupti-dev nvidia-driver
# Recommended packages:
#   libnvcuvid1
# The following NEW packages will be installed:
#   libcuinj64-8.0 nvidia-cuda-dev nvidia-cuda-toolkit nvidia-profiler
#   nvidia-visual-profiler
# 0 upgraded, 5 newly installed, 0 to remove and 4 not upgraded.
# Need to get 383 MB of archives.
# After this operation, 806 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 libcuinj64-8.0 amd64 8.0.61-1 [1,758 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 nvidia-cuda-dev amd64 8.0.61-1 [243 MB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 nvidia-profiler amd64 8.0.61-1 [2,624 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 nvidia-cuda-toolkit amd64 8.0.61-1 [22.4 MB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 nvidia-visual-profiler amd64 8.0.61-1 [113 MB]
# Fetched 383 MB in 15s (25.1 MB/s)
# Selecting previously unselected package libcuinj64-8.0:amd64.
# (Reading database ... 93714 files and directories currently installed.)
# Preparing to unpack .../libcuinj64-8.0_8.0.61-1_amd64.deb ...
# Unpacking libcuinj64-8.0:amd64 (8.0.61-1) ...
# Selecting previously unselected package nvidia-cuda-dev.
# Preparing to unpack .../nvidia-cuda-dev_8.0.61-1_amd64.deb ...
# Unpacking nvidia-cuda-dev (8.0.61-1) ...
# Selecting previously unselected package nvidia-profiler.
# Preparing to unpack .../nvidia-profiler_8.0.61-1_amd64.deb ...
# Unpacking nvidia-profiler (8.0.61-1) ...
# Selecting previously unselected package nvidia-cuda-toolkit.
# Preparing to unpack .../nvidia-cuda-toolkit_8.0.61-1_amd64.deb ...
# Unpacking nvidia-cuda-toolkit (8.0.61-1) ...
# Selecting previously unselected package nvidia-visual-profiler.
# Preparing to unpack .../nvidia-visual-profiler_8.0.61-1_amd64.deb ...
# Unpacking nvidia-visual-profiler (8.0.61-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libcuinj64-8.0:amd64 (8.0.61-1) ...
# Processing triggers for man-db (2.7.6.1-2) ...
# Setting up nvidia-profiler (8.0.61-1) ...
# Setting up nvidia-visual-profiler (8.0.61-1) ...
# Setting up nvidia-cuda-dev (8.0.61-1) ...
# Setting up nvidia-cuda-toolkit (8.0.61-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %% [markdown]
# # Link our Compilers to CUDA

# %%
! ln -s /usr/bin/gcc-6 /usr/local/cuda/bin/gcc
! ln -s /usr/bin/g++-6 /usr/local/cuda/bin/g++
# Out:
# ln: failed to create symbolic link '/usr/local/cuda/bin/gcc': File exists
# ln: failed to create symbolic link '/usr/local/cuda/bin/g++': File exists

# %% [markdown]
# # Install Cmake
#
#
#
#
# *  CMake is an open-source, cross-platform family of tools
# *  designed to build, test and package software.
# *  Used to control the software compilation process.
# *  by using simple platform and compiler independent configuration files,
# *  generate native makefiles and workspaces that can be used in the compiler environment of your choice.

# %%
# !apt-get install cmake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.9.1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %% [markdown]
# # Upload the Repo

# %%
# !git clone https://github.com/ShimaaElabd/CUDA-GPU-Contrast-Enhancement.git
# Out:
# fatal: destination path 'CUDA-GPU-Contrast-Enhancement' already exists and is not an empty directory.

# %%
# !ls
# Out:
# CUDA-GPU-Contrast-Enhancement
# cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64
# cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.1
# cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64
# cuda-repo-ubuntu1710-9-2-local-cublas-update-1_1.0-1_amd64.1
# datalab

# %%
# %cd CUDA-GPU-Contrast-Enhancement
# Out:
# /content/CUDA-GPU-Contrast-Enhancement

# %%
# !mkdir build
# %cd build
# Out:
# mkdir: cannot create directory ‘build’: File exists
# /content/CUDA-GPU-Contrast-Enhancement/build

# %%
# !ls /usr/local/cuda-9.2/samples/common/inc
# Out:
# cuda_drvapi_dynlink.c  helper_gl.h	 nvVector.h
# drvapi_error_string.h  helper_image.h	 paramgl.h
# dynlink		       helper_math.h	 param.h
# dynlink_d3d10.h        helper_string.h	 rendercheck_d3d10.h
# dynlink_d3d11.h        helper_timer.h	 rendercheck_d3d11.h
# exception.h	       multithreading.h  rendercheck_d3d9.h
# GL		       nvMath.h		 rendercheck_gles.h
# helper_cuda_drvapi.h   nvMatrix.h	 rendercheck_gl.h
# helper_cuda.h	       nvQuaternion.h	 timer.h
# helper_cusolver.h      nvrtc_helper.h
# helper_functions.h     nvShaderUtils.h

# %%
! export CUDA_TOOLKIT_ROOT_DIR=/usr/local/cuda-9.2/

# %% [markdown]
# # Cmake

# %%
# !cmake -D CUDA_TOOLKIT_ROOT_DIR=/usr/local/cuda-9.2/ ..
# Out:
# -- /usr/local/cuda-9.2/include
# -- /usr/local/cuda-9.2/
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/CUDA-GPU-Contrast-Enhancement/build

# %% [markdown]
# # Building NVCC (Make)

# %%
# !make
# Out:
# [ 16%] Linking CXX executable 5kk70-assignment-gpu
# [100%] Built target 5kk70-assignment-gpu

# %%
# !ls
# Out:
# 5kk70-assignment-gpu  gpu_out_hsl.ppm  in-color.jpg  n.pgm	  out_yuv.ppm
# CMakeCache.txt	      gpu_out.pgm      in.pgm	     out_hsl.ppm
# CMakeFiles	      gpu_out_rgb.ppm  in.ppm	     out.pgm
# cmake_install.cmake   gpu_out_yuv.ppm  Makefile      out_rgb.ppm

# %% [markdown]
# # Upload images to test

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c3d307c-e22c-4b7a-bb8d-bfcf9a5b4b07" name="files[]" multiple disabled />
#      <output id="result-4c3d307c-e22c-4b7a-bb8d-bfcf9a5b4b07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !ls
# Out:
# 5kk70-assignment-gpu  gpu_out_hsl.ppm  in-color.jpg  n.pgm	  out_yuv.ppm
# CMakeCache.txt	      gpu_out.pgm      in.pgm	     out_hsl.ppm
# CMakeFiles	      gpu_out_rgb.ppm  in.ppm	     out.pgm
# cmake_install.cmake   gpu_out_yuv.ppm  Makefile      out_rgb.ppm

# %% [markdown]
# # Run the Project on GPU

# %%
# !./5kk70-assignment-gpu
# Out:
# ====================================================
#  Running contrast enhancement for gray-scale images
# ====================================================
# Image size: 3648 x 2736
# ------------------------
# Starting CPU processing
# Processing time: 77.638000 (ms)
# ------------------------
# Starting GPU processing
# Processing time: 11.243000 (ms)
# ====================================================
#     Running contrast enhancement for color images
# ====================================================
# Image size: 3648 x 2736
# -------------------------------------
# Starting CPU processing
# -------------------------------------
# HSL processing time: 707.882996 (ms)
# YUV processing time: 504.007996 (ms)
# RGB processing time: 222.520004 (ms)
# -------------------------------------
# Starting GPU processing
# -------------------------------------
# HSL processing time: 17.556000 (ms)
# YUV processing time: 17.652000 (ms)
# RGB processing time: 52.845001 (ms)

# %%
# !ls
# Out:
# 5kk70-assignment-gpu  gpu_out_hsl.ppm  in-color.jpg  n.pgm	  out_yuv.ppm
# CMakeCache.txt	      gpu_out.pgm      in.pgm	     out_hsl.ppm
# CMakeFiles	      gpu_out_rgb.ppm  in.ppm	     out.pgm
# cmake_install.cmake   gpu_out_yuv.ppm  Makefile      out_rgb.ppm

# %% [markdown]
# # Output Images

# %%
files.download('out_hsl.ppm')

# %%
#files.download('out.pgm')

# %%
# %matplotlib inline

import matplotlib
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img_in_gray    =mpimg.imread('in.pgm')
img_in_color   =mpimg.imread('in.ppm')
img_out        =mpimg.imread('out.pgm')
img_out_rgb    =mpimg.imread('out_rgb.ppm')
img_in_out_yuv =mpimg.imread('out_yuv.ppm')
img_in_out_hsl =mpimg.imread('out_hsl.ppm')

print(" img_in_gray :")
plt.imshow(img_in_gray)
plt.show()

print("img_in_color: ")
plt.imshow(img_in_color)
plt.show()

print(" img_out:")
plt.imshow(img_out)
plt.show()

print(" img_out_rgb:")
plt.imshow(img_out_rgb)
plt.show()

print("img_in_out_yuv: ")
plt.imshow(img_in_out_yuv)
plt.show()

print("img_in_out_hsl: ")
plt.imshow(img_in_out_hsl)
plt.show()

print("done.")
# Out:
#  img_in_gray :
# img_in_color:
#  img_out:
#  img_out_rgb:
# img_in_out_yuv:
# img_in_out_hsl:
# done.
